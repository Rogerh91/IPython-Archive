# %%
1 + 1
# Out:
# 2

# %%
2 + 2
# Out:
# 4

# %%
50
# Out:
# 50

# %%
def add(n):
    return n + 1
add(1)
# Out:
# 2

# %%
import pandas as pd

# %%
PYTHON DO MAGIC\
# Out:
#   File "<ipython-input-6-41d6f5634503>", line 1
#     PYTHON DO MAGIC
#             ^
# SyntaxError: invalid syntax

# %%
BIG DATA IS TOO BIG
# Out:
#   File "<ipython-input-7-297b82b7d165>", line 1
#     BIG DATA IS TOO BIG
#            ^
# SyntaxError: invalid syntax

# %%
"BIG DATA IS TOO BIG" = BIG
# Out:
#   File "<ipython-input-8-55e2f07b8aff>", line 1
#     "BIG DATA IS TOO BIG" = BIG
#                                ^
# SyntaxError: can't assign to literal

# %%
BIG = "BIG DATA IS TOO"

# %%
BIG.append("BIG")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-d1d6bf66e988> in <module>()
# ----> 1 BIG.append("BIG")
#
# AttributeError: 'str' object has no attribute 'append'

# %%
1 + 1
# Out:
# 2

# %%
karma = pd.read_csv('../Downloads/KarmaCRM.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0a08cba8a29a> in <module>()
# ----> 1 karma = pd.read_csv('../Downloads/KarmaCRM.csv')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
karma = pd.read_csv('../Downloads/KarmaCRM.csv')

# %%
karma
# Out:
#                First name     Last name   Type  \
# 0                  Andrew        Eakins  False
# 1                   Kenny           Beh  False
# 2                 Alinser         Hoyos  False
# 3                  Manuel         Asian  False
# 4                    Mike         Orley  False
# 5                     NaN           NaN  False
# 6                    Glen       Furlong  False
# 7                     NaN           NaN  False
# 8                     NaN           NaN  False
# 9                     NaN           NaN  False
# 10                   Tina        McCord  False
# 11                 Janice         Salim  False
# 12                    NaN           NaN  False
# 13           brocantehome           NaN  False
# 14    info@schooldesk.net           NaN  False
# 15                    NaN           NaN  False
# 16                   Eric          Doub  False
# 17    ron@easyopticare.nl           NaN  False
# 18                    NaN           NaN  False
# ...

# %%
karma[:20]
# Out:
#              First name Last name   Type                             Name  \
# 0                Andrew    Eakins  False          Andrew and Wendy Eakins
# 1                 Kenny       Beh  False                        Kenny Beh
# 2               Alinser     Hoyos  False                    Alinser Hoyos
# 3                Manuel     Asian  False                     Manuel Asian
# 4                  Mike     Orley  False                       Mike Orley
# 5                   NaN       NaN  False                              NaN
# 6                  Glen   Furlong  False                     Glen Furlong
# 7                   NaN       NaN  False                              NaN
# 8                   NaN       NaN  False                              NaN
# 9                   NaN       NaN  False                              NaN
# 10                 Tina    McCord  False  Tina Harrison & Kathleen McCord
# 11               Janice     Salim  False                     Janice Salim
# ...

# %%
industry = karma['Industry']
print industry
# Out:
#   File "<ipython-input-5-c66ba79fa64a>", line 2
#     print industry
#                  ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
industry = karma['Industry']
    print industry
# Out:
#   File "<ipython-input-6-53b39acb0749>", line 2
#     print industry
#     ^
# IndentationError: Missing parentheses in call to 'print'

# %%
industry = karma['Industry']
industry
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-db9cf3787563> in <module>()
# ----> 1 industry = karma['Industry']
#       2 industry
#
# C:\Users\Asus\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1778             return self._getitem_multilevel(key)
#    1779         else:
# -> 1780             return self._getitem_column(key)
#    1781
#    1782     def _getitem_column(self, key):
#
# C:\Users\Asus\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    1785         # get column
#    1786         if self.columns.is_unique:
# -> 1787             return self._get_item_cache(key)
#    1788
#    1789         # duplicate columns & possible reduce dimensionaility
#
# C:\Users\Asus\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1066         res = cache.get(item)
# ...

# %%
industry = karma['industry']
industry
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# ...
# 3725             education
# 3726            consulting
# 3727            consulting
# 3728    telecommunications
# 3729            technology
# 3730                   NaN
# 3731         entertainment
# 3732                   NaN
# 3733             marketing
# 3734               no-info
# 3735         entertainment
# 3736         entertainment
# 3737                   NaN
# 3738                   NaN
# 3739           health-care
# Name: industry, Length: 3740, dtype: object

# %%
marketing = industry == "marketing"

# %%
marketing
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# ...
# 3725    False
# 3726    False
# 3727    False
# 3728    False
# 3729    False
# 3730    False
# 3731    False
# 3732    False
# 3733     True
# 3734    False
# 3735    False
# 3736    False
# 3737    False
# 3738    False
# 3739    False
# Name: industry, Length: 3740, dtype: bool

# %%
len(marketing)
# Out:
# 3740

# %%
karma
# Out:
#                First name     Last name   Type  \
# 0                  Andrew        Eakins  False
# 1                   Kenny           Beh  False
# 2                 Alinser         Hoyos  False
# 3                  Manuel         Asian  False
# 4                    Mike         Orley  False
# 5                     NaN           NaN  False
# 6                    Glen       Furlong  False
# 7                     NaN           NaN  False
# 8                     NaN           NaN  False
# 9                     NaN           NaN  False
# 10                   Tina        McCord  False
# 11                 Janice         Salim  False
# 12                    NaN           NaN  False
# 13           brocantehome           NaN  False
# 14    info@schooldesk.net           NaN  False
# 15                    NaN           NaN  False
# 16                   Eric          Doub  False
# 17    ron@easyopticare.nl           NaN  False
# 18                    NaN           NaN  False
# ...

# %%
marketing[['Name', 'Users']][:20]
# Out:
# Name     NaN
# Users    NaN
# Name: industry, dtype: object

# %%
marketing
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# ...
# 3725    False
# 3726    False
# 3727    False
# 3728    False
# 3729    False
# 3730    False
# 3731    False
# 3732    False
# 3733     True
# 3734    False
# 3735    False
# 3736    False
# 3737    False
# 3738    False
# 3739    False
# Name: industry, Length: 3740, dtype: bool

# %%
industry[marketing][['Name', 'Users']][:20]
# Out:
# Name     NaN
# Users    NaN
# Name: industry, dtype: object

# %%
marketing = Karma['industry'] == "marketing"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-418b36ded9e8> in <module>()
# ----> 1 marketing = Karma['industry'] == "marketing"
#
# NameError: name 'Karma' is not defined

# %%
marketing = karma['industry'] == "marketing"

# %%
marketing
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# ...
# 3725    False
# 3726    False
# 3727    False
# 3728    False
# 3729    False
# 3730    False
# 3731    False
# 3732    False
# 3733     True
# 3734    False
# 3735    False
# 3736    False
# 3737    False
# 3738    False
# 3739    False
# Name: industry, Length: 3740, dtype: bool

# %%
karma[marketing][['Name', 'Users']][:20]
# Out:
#                  Name  Users
# 131  Traci Tattersall      2
# 132  Aaron Tattersall      2
# 139        Ali Wilson     11
# 150       Tacye Vogel     27
# 151      Anne Ramallo      6
# 184       Yves Frerot     16
# 185    Sebastian Gika     16
# 186    Ernest Gergely     16
# 201    Dominik Wolski     16
# 213      Bettina Pape     29
# 214       Maha  Hilal      5
# 230      Sandra Kunze     29
# 233   Russell Rodrigo     10
# 234    Sanjay Haridas     10
# 239        Ben Lozano      2
# 241       Gali Soudak      1
# 300            Joy Xu      6
# 368       Lisa Gunter     17
# 381  Ignacia Elizalde      6
# 388      Jessica Hall     17
